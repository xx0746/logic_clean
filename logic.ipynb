# %%
import cx_Oracle
from enum import unique
class params_global():
    is_test = "True"
    # is_test = "False"

    nodata_exec_status = 2
"""
here to save all read config for Ezpass database
"""
class ezpass_db:
    # @unique
    class Authconfig:
        if params_global.is_test:
            # 测试环境cusrc
            ods_oracle_account = 'CUSRC/easipass'
            oracle_database_dbods = '192.168.129.149:1521/test12c'
            oracle_write_account = 'CUSRC:easipass'
            oracle_write_address = '192.168.129.149:1521/?service_name=test12c'
            oracle_write_account_alarm = 'DW_CUS_RC:easipass'
            oracle_write_address_alarm = '192.168.130.225:1521/?service_name=pdbcusdev'

            # # 测试环境 dw
            dw_oracle_account = 'BI_OPER/easipass'
            oracle_database_dbdw = '192.168.129.179:1521/testdw'

            # 测试环境BD_RISK
            ods_oracle_account = 'BD_RISK/easipass'
            oracle_database_dbods = '192.168.129.149:1521/test12c'
            # oracle_write_account = 'BD_RISK:easipass'
            # oracle_write_address = '192.168.129.149:1521/?service_name=test12c'

            dm_oracle_account = 'BD_RISK/infa4A9F'
            oracle_database_dbdm = '192.168.132.52:1521/dbdm'

            gold_oracle_account = 'n_epz_cus/n_epz_cus'
            oracle_database_gold = '192.168.131.125:1521/zmqwdb'

            alarm_oracle_account = 'DW_CUS_RC/easipass'
            oracle_database_alarm = '192.168.130.225:1521/pdbcusdev'

            lgsa_oracle_account = 'lgsa/lgsa'
            oracle_database_lgsa = '192.168.131.125:1521/zmqwdb'

            testlog_oracle_account = 'BD_RISK/testinfaer'
            oracle_database_testlog = '192.168.129.163:1521/TESTDMAPP'
        else:
            # 生产环境 CUSRC
            # ods_oracle_account = 'CUSRC/infa5F1D'
            # oracle_database_dbods = '192.168.132.12:1521/dbods'
            # oracle_write_account = 'CUSRC:infa5F1D'
            # oracle_write_address = '192.168.132.12:1521/?service_name=dbods'

            # 生产环境 BD_RISK
            oracle_write_account = 'BD_RISK:infa4A9F'
            oracle_write_address = '192.168.132.52:1521/?service_name=dbdm'
            # dbods
            ods_oracle_account = 'CUSRC/infa5F1D'
            oracle_database_dbods = '192.168.132.12:1521/dbods'
            # db_dw
            dw_oracle_account = 'BI_OPER/infa6D83'
            oracle_database_dbdw = '192.168.132.17:1521/dbdw'
            # db_dm
            dm_oracle_account = 'BD_RISK/infa4A9F'
            oracle_database_dbdm = '192.168.132.52:1521/dbdm'

            # Mongodb_config
            mongo_read_oper = 'ods_sens_oper:mgoD52F'
            mongo_ip = '192.168.132.74:27017'
            mongo_database = 'ods_sens_zmxpq'
            mongo_table = 'credit'
# from loguru import logger
import time
import pandas as pd
class Read_Oracle(object):
    def __init__(self):
        self.link = None
        self.account = None

    def read_oracle_df(self, sql):
        print(self.account)
        print(self.link)
        conn = cx.connect(self.account+'@'+self.link, encoding='utf8')
        data_gen = pd.read_sql(con=conn, sql=sql, chunksize=100000)
        gen_list = []
        for gen in data_gen:
            gen_list.append(gen)
        if len(gen_list) ==0:
            print('Sql cannot find table, please check database')
            data_df = None
        else:
            data_df = pd.concat(gen_list)
        return data_df


    def read_oracle(self, sql, database):
        start_time = time.time()
        """
        :arg
            :param sql : 读取的select 脚本
            :param databse ：目标database ； dbods、dbdw、dbdm
        :return
            返回查询的结果dataframe
        """
        sql = sql
        if database == 'dbods':
            self.link = ezpass_db.Authconfig.oracle_database_dbods
            self.account = ezpass_db.Authconfig.ods_oracle_account
        elif database == 'dbdw':
            self.link = ezpass_db.Authconfig.oracle_database_dbdw
            self.account = ezpass_db.Authconfig.dw_oracle_account
        elif database == 'dbdm':
            self.link = ezpass_db.Authconfig.oracle_database_dbdm
            self.account = ezpass_db.Authconfig.dm_oracle_account
        elif database == 'dbgold':
            self.link = ezpass_db.Authconfig.oracle_database_gold
            self.account = ezpass_db.Authconfig.gold_oracle_account
        elif database == 'dbalarm':
            self.link = ezpass_db.Authconfig.oracle_database_alarm
            self.account = ezpass_db.Authconfig.alarm_oracle_account
        elif database == 'dblgsa':
            self.link = ezpass_db.Authconfig.oracle_database_lgsa
            self.account = ezpass_db.Authconfig.lgsa_oracle_account
        elif database == 'testlog':
            self.link = ezpass_db.Authconfig.oracle_database_testlog
            self.account = ezpass_db.Authconfig.testlog_oracle_account
        else:
            print('read_oracle config error, please match your input sql and db')
            return

        data_df = self.read_oracle_df(sql)
        if data_df is None:
            data_df = pd.DataFrame()
        if data_df is not None:
            data_df = data_df.fillna('N/A')
        end_time = time.time()
        consum_time = end_time - start_time
        print('Read Table successfully! , Total read time spent {}s'.format(str(consum_time)[:5]))
        return data_df
def deal_context_dic(df):
    temp_dic = {}
    str = "{"
    temp_dic['businessStartTime'] = datetime.datetime.now()
    temp_dic['businessEndTime'] = datetime.datetime.now()
    temp_dic['entry'] = df['entry']
    for key, value in temp_dic.items():
        str += "\"%s\":\"%s\"," % (key, value)
    str = str[:-1]
    return str + "}"
def deal_entry_dic(df):
    temp_dic = {}
    str = "{"
    temp_dic['entryId'] = df['ENTRY_ID']
    temp_dic['entryIdCompare'] = df['ENTRY_ID_COMPARE']
    temp_dic['comparison'] = df['COMPARISON']
    temp_dic['ownerCode'] = df['CONSIGN_SCC']
    temp_dic['ownerName'] = df['CONSIGN_NAME']
    temp_dic['ownerCodeCompare'] = df['CONSIGN_SCC_COMPARE']
    temp_dic['ownerNameCompare'] = df['CONSIGN_NAME_COMPARE']
    for key, value in temp_dic.items():
        str += "\"%s\":\"%s\"," % (key, value)
    str = str[:-1]
    return str + "},"
def deal_comparison_dic(df):
    temp_dic = {}
    str = "{"
    temp_dic['code_t'] = df['G_NAME']
    temp_dic['qty1'] = df['G_QTY']
    temp_dic['originCountry'] = df['ORIGIN_COUNTRY']
    temp_dic['codeTCompare'] = df['G_NAME_COMPARE']
    temp_dic['qty1Compare'] = df['G_QTY_COMPARE']
    temp_dic['originCountryCompare'] = df['ORIGIN_COUNTRY_COMPARE']
    for key, value in temp_dic.items():
        str += "\"%s\":\"%s\"," % (key, value)
    str = str[:-1]
    return str + "},"
import cx_Oracle as cx
import pandas as pd
import os
import datetime
from loguru import logger
import time
pd.set_option('display.max_columns', None)
from config.auth_config import ezpass_db
os.environ['NLS_LANG'] = 'SIMPLIFIED CHINESE_CHINA.UTF8'
def deal_context_dic(df):
    temp_dic = {}
    str = "{"
    temp_dic['businessStartTime'] = datetime.datetime.now()
    temp_dic['businessEndTime'] = datetime.datetime.now()
    temp_dic['entry'] = df['entry']
    for key, value in temp_dic.items():
        str += "\"%s\":\"%s\"," % (key, value)
    str = str[:-1]
    return str + "}"
def deal_entry_dic(df):
    temp_dic = {}
    str = "{"
    temp_dic['entryId'] = df['ENTRY_ID']
    temp_dic['entryIdCompare'] = df['ENTRY_ID_COMPARE']
    temp_dic['comparison'] = df['COMPARISON']
    temp_dic['ownerCode'] = df['CONSIGN_SCC']
    temp_dic['ownerName'] = df['CONSIGN_NAME']
    temp_dic['ownerCodeCompare'] = df['CONSIGN_SCC_COMPARE']
    temp_dic['ownerNameCompare'] = df['CONSIGN_NAME_COMPARE']
    for key, value in temp_dic.items():
        str += "\"%s\":\"%s\"," % (key, value)
    str = str[:-1]
    return str + "},"
def deal_comparison_dic(df):
    temp_dic = {}
    str = "{"
    temp_dic['code_t'] = df['G_NAME']
    temp_dic['qty1'] = df['G_QTY']
    temp_dic['originCountry'] = df['ORIGIN_COUNTRY']
    temp_dic['codeTCompare'] = df['G_NAME_COMPARE']
    temp_dic['qty1Compare'] = df['G_QTY_COMPARE']
    temp_dic['originCountryCompare'] = df['ORIGIN_COUNTRY_COMPARE']
    for key, value in temp_dic.items():
        str += "\"%s\":\"%s\"," % (key, value)
    str = str[:-1]
    return str + "},"

# %%
import cx_Oracle as cx
import pandas as pd
import os
from loguru import logger
from sqlalchemy import types, create_engine
from risk_models.config.auth_config import ezpass_db
from risk_models.config.read_config.read_func import Read_Oracle
import datetime
import time
from sqlalchemy.types import *

os.environ['NLS_LANG'] = 'SIMPLIFIED CHINESE_CHINA.UTF8'


class Write_Oracle_Alarm(object):
    def __init__(self):
        # TODO 需要修改
        self.dmlink = ezpass_db.Authconfig.oracle_database_dbdm
        self.dwlink = ezpass_db.Authconfig.oracle_database_dbdw
        self.odslink = ezpass_db.Authconfig.oracle_database_dbods
        self.account = ezpass_db.Authconfig.ods_oracle_account
        self.write_account = ezpass_db.Authconfig.oracle_write_account_alarm
        self.write_address = ezpass_db.Authconfig.oracle_write_address_alarm
        # 目前只考虑一个conn，以后有多个写入地址再加
        self.conn = create_engine(f"oracle+cx_oracle://{self.write_account}@{self.write_address}",
                                  encoding='utf-8', convert_unicode=True)
        self.conn.autocommit = True

    def get_max_index(self, table_name):
        """
        :param table_name: 旧表表名
        :return: 返回最大的ID
        """
        read_sql = f'select max("ID") as id from {table_name.lower()}'
        # todo 这里的读取用到了dbdm是因为切换了生产环境，原本是dbods
        s_id = Read_Oracle().read_oracle(sql=read_sql, database='dbalarm')
        if s_id is None:
            return 0
        else:
            return 0 if s_id['ID'].values[0] == 'N/A' else s_id['ID'].values[0]

    def get_first_line(self, table_name):
        read_sql = f'select * from {table_name.lower()} where rownum = 1 '
        # todo 这里的读取用到了dbdm是因为切换了生产环境，原本是dbods
        old_df = Read_Oracle().read_oracle(sql=read_sql, database='dbdm')
        return old_df

    def clean_index(self, new_df, old_table_name):
        """
        清洗newdf的index
        :param new_df:
        :param old_table_name:
        :return:
        """
        new_df = new_df.reset_index()
        new_df = new_df.drop(axis=1, columns=['ID']).rename(columns={'index': 'ID'})
        max_id = self.get_max_index(old_table_name)
        if max_id is not None:
            new_df.loc[:, 'ID'] = new_df.loc[:, 'ID'].apply(lambda x: x + max_id + 1)
        else:
            pass
        new_df.set_index('ID')

        return new_df

    def add_lastupdate(self, new_df):
        now_time = datetime.datetime.now()
        now_time = datetime.datetime.strftime(now_time, format='%Y-%m-%d %H:%M:%S')
        new_df.loc[:, 'LASTUPDATE'] = now_time
        new_df.loc[:, 'LASTUPDATE'] = pd.to_datetime(new_df.loc[:, 'LASTUPDATE'], format='%Y-%m-%d %H:%M:%S')

        return new_df

    def add_iscurrent(self, new_df):
        new_df.loc[:, 'ISCURRENT'] = 1
        return new_df

    def change_lastupdate(self, old_table_name, org_code, alarm):
        """
        :param old_table_name: 表名
        :param org_code: 企业信用代码
        :param alarm: [model_code, child_mode_code] 主模块id和子模块id
        :return: None
        """
        now_time = datetime.datetime.now()
        now_time = datetime.datetime.strftime(now_time, format='%Y-%m-%d %H:%M:%S')
        if org_code is not None and alarm is None:
            try:
                self.conn.execute(
                    "update {} set LASTUPDATE =to_date('{}','yyyy-mm-dd hh24:mi:ss') where iscurrent = 1 and org_code ='{}'".format(
                        old_table_name, now_time, org_code))
            except Exception as e:
                logger.error(e)
        elif alarm is not None:
            if org_code is not None and len(alarm) == 2:
                model_code = alarm[0]
                child_mode_code = alarm[1]
                if child_mode_code == '':
                    try:
                        self.conn.execute(
                            "update {} set LASTUPDATE =to_date('{}','yyyy-mm-dd hh24:mi:ss') where iscurrent = 1 and org_code ='{}' and model_code = '{}'".format(
                                old_table_name, now_time, org_code, model_code))
                    except Exception as e:
                        logger.error(e)
                else:
                    try:
                        self.conn.execute(
                            "update {} set LASTUPDATE =to_date('{}','yyyy-mm-dd hh24:mi:ss') where iscurrent = 1 and org_code ='{}' and model_code = '{}' and child_model_code ='{}'".format(
                                old_table_name, now_time, org_code, model_code, child_mode_code))
                    except Exception as e:
                        logger.error(e)
            elif org_code is None and len(alarm) == 2:
                model_code = alarm[0]
                child_mode_code = alarm[1]
                if child_mode_code == '':
                    try:
                        self.conn.execute(
                            "update {} set LASTUPDATE =to_date('{}','yyyy-mm-dd hh24:mi:ss') where iscurrent = 1 and model_code = '{}'".format(
                                old_table_name, now_time,  model_code))
                    except Exception as e:
                        logger.error(e)
                else:
                    try:
                        self.conn.execute(
                            "update {} set LASTUPDATE =to_date('{}','yyyy-mm-dd hh24:mi:ss') where iscurrent = 1 and model_code = '{}' and child_model_code ='{}'".format(
                                old_table_name, now_time, model_code, child_mode_code))
                    except Exception as e:
                        logger.error(e)
        elif org_code is None:
            try:
                self.conn.execute(
                    "update {} set LASTUPDATE =to_date('{}','yyyy-mm-dd hh24:mi:ss') where iscurrent = 1 ".format(old_table_name, now_time))
            except Exception as e:
                logger.error(e)
        else:
            logger.warning('change_lastupdate func params error, please check params')

    def change_iscurrent(self, old_table_name, org_code, alarm):
        if org_code is not None and alarm is None:
            try:
                self.conn.execute("update {} set ISCURRENT = 0  where iscurrent = 1 and org_code ='{}'".format(old_table_name, org_code))
            except Exception as e:
                logger.error(e)
        elif alarm is not None:
            if org_code is not None and len(alarm) == 2:
                model_code = alarm[0]
                child_mode_code = alarm[1]
                if child_mode_code == '':
                    try:
                        self.conn.execute(
                            "update {} set ISCURRENT = 0  where iscurrent = 1 and org_code ='{}' and model_code = '{}'".format(old_table_name, org_code, model_code))
                    except Exception as e:
                        logger.error(e)
                else:
                    try:
                        self.conn.execute(
                            "update {} set ISCURRENT = 0  where iscurrent = 1 and org_code ='{}' and model_code = '{}' and child_model_code ='{}'".format(
                                old_table_name, org_code, model_code, child_mode_code))
                    except Exception as e:
                        logger.error(e)
            elif org_code is None and len(alarm) == 2:
                model_code = alarm[0]
                child_mode_code = alarm[1]
                if child_mode_code == '':
                    try:
                        self.conn.execute(
                            "update {} set ISCURRENT = 0 where iscurrent = 1 and model_code = '{}'".format(old_table_name, model_code))
                    except Exception as e:
                        logger.error(e)
                else:
                    try:
                        self.conn.execute(
                            "update {} set ISCURRENT = 0 where iscurrent = 1 and model_code = '{}' and child_model_code ='{}'".format(
                                old_table_name, model_code, child_mode_code))
                    except Exception as e:
                        logger.error(e)
        elif org_code is None:
            try:
                self.conn.execute("update {} set ISCURRENT = 0 where iscurrent = 1 ".format(old_table_name))
            except Exception as e:
                logger.error(e)
        else:
            logger.warning('change_iscurrent_func params error, please check params')

    @logger.catch()
    def write_oracle(self, table_name, new_df, org_code, alarm, iscurrent=True, alarm_code = None):
        """
        风控产品封装的写入接口
        :param iscurrent: 是否需要在插入的时候更新iscurrent
        :param table_name: 需要写入的表名
        :param new_df: 写入的对象dataframe
        :param org_code: 需要更新的企业信用代码
        :param alarm:  [model_code, child_mode_code] 主模块id和子模块id
        :return: None
        """
        if new_df is None:
            return
        start_time = time.time()
        new_df = self.clean_index(new_df, table_name)
        print(new_df)
        new_df = self.add_lastupdate(new_df)
        new_df = self.add_iscurrent(new_df)
        self.change_lastupdate(table_name, org_code, alarm)
        if iscurrent:
            self.change_iscurrent(table_name, org_code, alarm)
        # old_df = self.get_first_line(table_name)

        for key, value in dict(new_df.dtypes).items():
            # 如果不对object的columns进行一次astype（str）就会报错
            if value == 'object':
                new_df.loc[:, '{}'.format(key)] = new_df.loc[:, '{}'.format(key)].astype(str)

        def set_d_type_dict(df):
            type_dict = {}
            for i, j in zip(df.columns, df.dtypes):
                if "object" in str(j):
                    type_dict.update({i: VARCHAR(512)})
                if "float" in str(j):
                    type_dict.update({i: DECIMAL(20, 5)})
                if "int" in str(j):
                    type_dict.update({i: DECIMAL(20)})
            return type_dict

        logger.info('Processing... Writing {} rows into database'.format(len(new_df)))
        d_type = set_d_type_dict(new_df)
        new_df.to_sql(name=table_name.lower(), con=self.conn, if_exists='append', index=False, dtype=d_type, chunksize=2000)

        end_time = time.time()
        consum_time = end_time - start_time
        logger.info('Insert data into {} successfully! Total write time spent {}s'.format(table_name.upper(), str(consum_time)[:5]))

# %%
sql_text = f'''
        select
        t1.ID,
        t1.ENTRY_ID,
        t1.I_E_PORT,
        t1.D_DATE,
        t1.CONSIGN_SCC,
        t1.CONSIGN_CODE,
        t1.CONSIGN_NAME,
        t1.OWNER_CODE_SCC as CORP_CREDIT_CODE,
        t1.ENTRY_ID as BUSINESS_NO,
--         t1.OWNER_CODE_SCC as BUSINESS_NO,
        t1.OWNER_CODE,
        t1.OWNER_NAME,
        t1.TRADE_MODE,
        t1.G_NAME,
        t1.G_QTY,
        t1.ORIGIN_COUNTRY,
        t2.ENTRY_ID as ENTRY_ID_COMPARE,
        t2.I_E_PORT as I_E_PORT_COMPARE,
        t2.D_DATE as D_DATE_COMPARE,
        t2.OWNER_CODE_SCC as OWNER_CODE_SCC_COMPARE,
        t2.OWNER_CODE as OWNER_CODE_COMPARE,
        t2.OWNER_NAME as OWNER_NAME_COMPARE,
        t2.TRADE_MODE as TRADE_MODE_COMPARE,
        t2.CONSIGN_SCC AS CONSIGN_SCC_COMPARE,
        t2.CONSIGN_CODE AS CONSIGN_CODE_COMPARE,
        t2.CONSIGN_NAME AS CONSIGN_NAME_COMPARE,
        t2.G_NAME as G_NAME_COMPARE,
        t2.G_QTY as G_QTY_COMPARE,
        t2.ORIGIN_COUNTRY as ORIGIN_COUNTRY_COMPARE
        from DW_CUS_RC.BD_RISK_CROSS_TRADE_ORIGIN_CLN t1
        join DW_CUS_RC.BD_RISK_CROSS_TRADE_ORIGIN_CLN t2
        on t1.CONSIGN_SCC = t2.CONSIGN_SCC
        and t1.G_NAME = t2.G_NAME
        and t1.G_QTY = t2.G_QTY
        and t1.ORIGIN_COUNTRY != t2.ORIGIN_COUNTRY
        and t1.TRADE_MODE != t2.TRADE_MODE
                    '''
origin_country_df = Read_Oracle().read_oracle(sql=sql_text, database='dbalarm')
# Out:
# DW_CUS_RC/easipass
# 192.168.130.225:1521/pdbcusdev
# 2022-06-15 18:16:42.070 | INFO     | risk_models.config.read_config.read_func:read_oracle:73 - Read Table successfully! , Total read time spent 1.264s

# %%
origin_country_df
# Out:
#    ID            ENTRY_ID I_E_PORT    D_DATE         CONSIGN_SCC CONSIGN_CODE  \
# 0   3  224020221000000579     2249  20220601  91310000785178414H            2
# 1   2  224020221000000580     2249  20220601  91310000785178414H            2
# 2   6  224020221000000579     2249  20220601  91310000785178414H            2
# 3   5  224020221000000580     2249  20220601  91310000785178414H            2
#
#      CONSIGN_NAME    CORP_CREDIT_CODE         BUSINESS_NO  OWNER_CODE  \
# 0  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000579  3122S60004
# 1  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580  3122S60004
# 2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000579  3122S60004
# 3  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580  3122S60004
#
#      OWNER_NAME TRADE_MODE G_NAME G_QTY ORIGIN_COUNTRY    ENTRY_ID_COMPARE  \
# 0  上海元初国际物流有限公司       0110    发动机    10            BEN  224020221000000580
# 1  上海元初国际物流有限公司       5034    发动机    10            CAN  224020221000000579
# 2  上海元初国际物流有限公司       0110   发动机2    10            ANG  224020221000000580
# 3  上海元初国际物流有限公司       5034   发动机2    10            BOT  224020221000000579
#
#   I_E_PORT_COMPARE D_DATE_COMPARE OWNER_CODE_SCC_COMPARE OWNER_CODE_COMPARE  \
# 0             2249       20220601     913100006929421297         3122S60004
# 1             2249       20220601     913100006929421297         3122S60004
# 2             2249       20220601     913100006929421297         3122S60004
# 3             2249       20220601     913100006929421297         3122S60004
#
#   OWNER_NAME_COMPARE TRADE_MODE_COMPARE CONSIGN_SCC_COMPARE  \
# 0       上海元初国际物流有限公司               5034  91310000785178414H
# 1       上海元初国际物流有限公司               0110  91310000785178414H
# 2       上海元初国际物流有限公司               5034  91310000785178414H
# 3       上海元初国际物流有限公司               0110  91310000785178414H
#
#   CONSIGN_CODE_COMPARE CONSIGN_NAME_COMPARE G_NAME_COMPARE G_QTY_COMPARE  \
# 0                    2       施洁医疗技术（上海）有限公司            发动机            10
# 1                    2       施洁医疗技术（上海）有限公司            发动机            10
# 2                    2       施洁医疗技术（上海）有限公司           发动机2            10
# 3                    2       施洁医疗技术（上海）有限公司           发动机2            10
#
#   ORIGIN_COUNTRY_COMPARE
# 0                    CAN
# 1                    BEN
# 2                    BOT
# 3                    ANG

# %%
# origin_country_df["ENTRY_ID"].str.cat(origin_country_df["ENTRY_ID_COMPARE"],sep="-")
list_temp = list(origin_country_df["ENTRY_ID"].str.cat(origin_country_df["ENTRY_ID_COMPARE"],sep="-"))

# %%
list_temp
# Out:
# ['224020221000000580-224020221000000579',
#  '224020221000000579-224020221000000580']

# %%
origin_country_df = Read_Oracle().read_oracle(sql=sql_text, database='dbalarm')
origin_country_df['COMPARISON'] = origin_country_df.apply(lambda x: deal_comparison_dic(x), axis=1)
origin_country_df.groupby(['ENTRY_ID', 'CORP_CREDIT_CODE', 'BUSINESS_NO', 'ENTRY_ID_COMPARE']).agg({'COMPARISON': 'sum', 'ENTRY_ID': 'first', 'ENTRY_ID_COMPARE': 'first', 'CORP_CREDIT_CODE': 'first', 'OWNER_CODE': 'first', 'OWNER_NAME': 'first', 'OWNER_CODE_SCC_COMPARE': 'first', 'OWNER_CODE_COMPARE': 'first', 'OWNER_NAME_COMPARE': 'first', 'CONSIGN_SCC': 'first', 'CONSIGN_SCC_COMPARE': 'first', 'CONSIGN_NAME': 'first', 'CONSIGN_NAME_COMPARE': 'first',})
origin_country_df['COMPARISON'] = origin_country_df['COMPARISON'].map(lambda x: "[" + x[: -1] + "]")
origin_country_df['entry'] = origin_country_df.apply(lambda x: deal_entry_dic(x), axis=1)
origin_country_df.drop(columns=['CORP_CREDIT_CODE'], inplace=True)
 # 以下为赋值
entry_df = origin_country_df.groupby(['CORP_CREDIT_CODE', 'BUSINESS_NO']).agg({'entry': 'first', 'OWNER_CODE': 'first', 'OWNER_NAME': 'first'})
entry_df['entry'] = entry_df['entry'].map(lambda x: "[" + x[: -1] + "]")
entry_df['CONTEXT'] = entry_df.apply(lambda x: deal_context_dic(x), axis=1)
entry_df['ID'] = 0
entry_df["CUSTOMS_CODE"] = "2249"
entry_df["TYPE_FIRST"] = "GNYTJKYJ"
entry_df["TYPE_SECOND"] = "BSWL"
entry_df["BUSINESS_TYPE"] = "61"
entry_df["ORDER_TYPE"] = "trade"
entry_df["RESOLVE_STATUS"] = "0"
entry_df["RISK_LEVEL"] = "3"
# entry_df["LABEL"] = "一二线原产国预警"
entry_df["TRADE_CODE"] = entry_df["OWNER_CODE"]
entry_df["CORP_NAME"] = entry_df["OWNER_NAME"]
entry_df.drop(columns=['entry', 'OWNER_NAME', 'OWNER_CODE'], inplace=True)
entry_df = entry_df.reset_index()

entry_df
# Out:
# DW_CUS_RC/easipass
# 192.168.130.225:1521/pdbcusdev
# 2022-06-14 17:11:51.414 | INFO     | risk_models.config.read_config.read_func:read_oracle:73 - Read Table successfully! , Total read time spent 5.610s
#               index                                            CONTEXT  ID  \
# 0       BUSINESS_NO  {"businessStartTime":"2022-06-14 17:11:51.4755...   0
# 1  CORP_CREDIT_CODE  {"businessStartTime":"2022-06-14 17:11:51.4765...   0
#
#   CUSTOMS_CODE TYPE_FIRST TYPE_SECOND BUSINESS_TYPE ORDER_TYPE RESOLVE_STATUS  \
# 0         2249   GNYTJKYJ        BSWL            61      trade              0
# 1         2249   GNYTJKYJ        BSWL            61      trade              0
#
#   RISK_LEVEL  TRADE_CODE     CORP_NAME
# 0          3  3122S60004  上海元初国际物流有限公司
# 1          3  3122S60004  上海元初国际物流有限公司

# %%
sql_text = f'''
        select
        t1.ID,
        t1.ENTRY_ID,
        t1.I_E_PORT,
        t1.D_DATE,
        t1.CONSIGN_SCC,
        t1.CONSIGN_CODE,
        t1.CONSIGN_NAME,
        t1.OWNER_CODE_SCC as CORP_CREDIT_CODE,
        t1.ENTRY_ID as BUSINESS_NO,
--         t1.OWNER_CODE_SCC as BUSINESS_NO,
        t1.OWNER_CODE,
        t1.OWNER_NAME,
        t1.TRADE_MODE,
        t1.G_NAME,
        t1.G_QTY,
        t1.ORIGIN_COUNTRY,
        t2.ENTRY_ID as ENTRY_ID_COMPARE,
        t2.I_E_PORT as I_E_PORT_COMPARE,
        t2.D_DATE as D_DATE_COMPARE,
        t2.OWNER_CODE_SCC as OWNER_CODE_SCC_COMPARE,
        t2.OWNER_CODE as OWNER_CODE_COMPARE,
        t2.OWNER_NAME as OWNER_NAME_COMPARE,
        t2.TRADE_MODE as TRADE_MODE_COMPARE,
        t2.CONSIGN_SCC AS CONSIGN_SCC_COMPARE,
        t2.CONSIGN_CODE AS CONSIGN_CODE_COMPARE,
        t2.CONSIGN_NAME AS CONSIGN_NAME_COMPARE,
        t2.G_NAME as G_NAME_COMPARE,
        t2.G_QTY as G_QTY_COMPARE,
        t2.ORIGIN_COUNTRY as ORIGIN_COUNTRY_COMPARE
        from DW_CUS_RC.BD_RISK_CROSS_TRADE_ORIGIN_CLN t1
        join DW_CUS_RC.BD_RISK_CROSS_TRADE_ORIGIN_CLN t2
        on t1.CONSIGN_SCC = t2.CONSIGN_SCC
        and t1.G_NAME = t2.G_NAME
        and t1.G_QTY = t2.G_QTY
        and t1.ORIGIN_COUNTRY != t2.ORIGIN_COUNTRY
        and t1.TRADE_MODE != t2.TRADE_MODE
                    '''
origin_country_df = Read_Oracle().read_oracle(sql=sql_text, database='dbalarm')
origin_country_df=origin_country_df.loc[origin_country_df['TRADE_MODE_COMPARE']!='5034']
origin_country_df
# Out:
# DW_CUS_RC/easipass
# 192.168.130.225:1521/pdbcusdev
# 2022-06-15 16:52:48.480 | INFO     | risk_models.config.read_config.read_func:read_oracle:73 - Read Table successfully! , Total read time spent 1.131s
#    ID            ENTRY_ID I_E_PORT    D_DATE         CONSIGN_SCC CONSIGN_CODE  \
# 0   3  224020221000000580     2249  20220601  91310000785178414H            2
#
#      CONSIGN_NAME    CORP_CREDIT_CODE         BUSINESS_NO  OWNER_CODE  \
# 0  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580  3122S60004
#
#      OWNER_NAME TRADE_MODE G_NAME G_QTY ORIGIN_COUNTRY    ENTRY_ID_COMPARE  \
# 0  上海元初国际物流有限公司       5034    发动机    10            CAN  224020221000000579
#
#   I_E_PORT_COMPARE D_DATE_COMPARE OWNER_CODE_SCC_COMPARE OWNER_CODE_COMPARE  \
# 0             2249       20220601     913100006929421297         3122S60004
#
#   OWNER_NAME_COMPARE TRADE_MODE_COMPARE CONSIGN_SCC_COMPARE  \
# 0       上海元初国际物流有限公司               0110  91310000785178414H
#
#   CONSIGN_CODE_COMPARE CONSIGN_NAME_COMPARE G_NAME_COMPARE G_QTY_COMPARE  \
# 0                    2       施洁医疗技术（上海）有限公司            发动机            10
#
#   ORIGIN_COUNTRY_COMPARE
# 0                    USA

# %%
sql_text = f'''
        select
        t1.ID,
        t1.ENTRY_ID,
        t1.I_E_PORT,
        t1.D_DATE,
        t1.CONSIGN_SCC,
        t1.CONSIGN_CODE,
        t1.CONSIGN_NAME,
        t1.OWNER_CODE_SCC as CORP_CREDIT_CODE,
        t1.ENTRY_ID as BUSINESS_NO,
--         t1.OWNER_CODE_SCC as BUSINESS_NO,
        t1.OWNER_CODE,
        t1.OWNER_NAME,
        t1.TRADE_MODE,
        t1.G_NAME,
        t1.G_QTY,
        t1.ORIGIN_COUNTRY,
        t2.ENTRY_ID as ENTRY_ID_COMPARE,
        t2.I_E_PORT as I_E_PORT_COMPARE,
        t2.D_DATE as D_DATE_COMPARE,
        t2.OWNER_CODE_SCC as OWNER_CODE_SCC_COMPARE,
        t2.OWNER_CODE as OWNER_CODE_COMPARE,
        t2.OWNER_NAME as OWNER_NAME_COMPARE,
        t2.TRADE_MODE as TRADE_MODE_COMPARE,
        t2.CONSIGN_SCC AS CONSIGN_SCC_COMPARE,
        t2.CONSIGN_CODE AS CONSIGN_CODE_COMPARE,
        t2.CONSIGN_NAME AS CONSIGN_NAME_COMPARE,
        t2.G_NAME as G_NAME_COMPARE,
        t2.G_QTY as G_QTY_COMPARE,
        t2.ORIGIN_COUNTRY as ORIGIN_COUNTRY_COMPARE
        from DW_CUS_RC.BD_RISK_CROSS_TRADE_ORIGIN_CLN t1
        join DW_CUS_RC.BD_RISK_CROSS_TRADE_ORIGIN_CLN t2
        on t1.CONSIGN_SCC = t2.CONSIGN_SCC
        and t1.G_NAME = t2.G_NAME
        and t1.G_QTY = t2.G_QTY
        and t1.ORIGIN_COUNTRY != t2.ORIGIN_COUNTRY
        and t1.TRADE_MODE != t2.TRADE_MODE
                    '''
origin_country_df = Read_Oracle().read_oracle(sql=sql_text, database='dbalarm')
  # 改动在这
if origin_country_df is not None and len(origin_country_df) != 0:
    origin_country_df=origin_country_df.loc[origin_country_df['TRADE_MODE']=='5034']
    origin_country_df['COMPARISON'] = origin_country_df.apply(lambda x: deal_comparison_dic(x), axis=1)
    origin_country_df = origin_country_df.groupby(['ENTRY_ID', 'CORP_CREDIT_CODE', 'BUSINESS_NO', 'ENTRY_ID_COMPARE']).agg({'COMPARISON': 'sum', 'ENTRY_ID': 'first', 'ENTRY_ID_COMPARE': 'first', 'CORP_CREDIT_CODE': 'first', 'OWNER_CODE': 'first', 'OWNER_NAME': 'first', 'OWNER_CODE_SCC_COMPARE': 'first', 'OWNER_CODE_COMPARE': 'first', 'OWNER_NAME_COMPARE': 'first', 'CONSIGN_SCC': 'first', 'CONSIGN_SCC_COMPARE': 'first', 'CONSIGN_NAME': 'first', 'CONSIGN_NAME_COMPARE': 'first',})
    origin_country_df['COMPARISON'] = origin_country_df['COMPARISON'].map(lambda x: "[" + x[: -1] + "]")
    origin_country_df['entry'] = origin_country_df.apply(lambda x: deal_entry_dic(x), axis=1)
    origin_country_df.drop(columns=['CORP_CREDIT_CODE'], inplace=True)

    # entry_df = origin_country_df.groupby(['CORP_CREDIT_CODE', 'BUSINESS_NO']).agg({'entry': 'sum',  'OWNER_CODE': 'first', 'OWNER_NAME': 'first'})
    entry_df = origin_country_df.groupby(['CORP_CREDIT_CODE', 'BUSINESS_NO']).agg({'entry': 'first', 'OWNER_CODE': 'first', 'OWNER_NAME': 'first'})
    entry_df['entry'] = entry_df['entry'].map(lambda x: "[" + x[: -1] + "]")
    entry_df['CONTEXT'] = entry_df.apply(lambda x: deal_context_dic(x), axis=1)
    entry_df['ID'] = 0
    entry_df["CUSTOMS_CODE"] = "2249"
    entry_df["TYPE_FIRST"] = "GNYTJKYJ"
    entry_df["TYPE_SECOND"] = "BSWL"
    entry_df["BUSINESS_TYPE"] = "61"
    entry_df["ORDER_TYPE"] = "trade"
    entry_df["RESOLVE_STATUS"] = "0"
    entry_df["RISK_LEVEL"] = "3"
    # entry_df["LABEL"] = "一二线原产国预警"
    entry_df["TRADE_CODE"] = entry_df["OWNER_CODE"]
    entry_df["CORP_NAME"] = entry_df["OWNER_NAME"]
    entry_df.drop(columns=['entry', 'OWNER_NAME', 'OWNER_CODE'], inplace=True)
    entry_df = entry_df.reset_index()
    print(entry_df)
# Out:
# DW_CUS_RC/easipass
# 192.168.130.225:1521/pdbcusdev
# 2022-06-15 18:17:05.236 | INFO     | risk_models.config.read_config.read_func:read_oracle:73 - Read Table successfully! , Total read time spent 1.552s
#      CORP_CREDIT_CODE         BUSINESS_NO  \
# 0  913100006929421297  224020221000000580
#
#                                              CONTEXT  ID CUSTOMS_CODE  \
# 0  {"businessStartTime":"2022-06-15 18:17:05.2998...   0         2249
#
#   TYPE_FIRST TYPE_SECOND BUSINESS_TYPE ORDER_TYPE RESOLVE_STATUS RISK_LEVEL  \
# 0   GNYTJKYJ        BSWL            61      trade              0          3
#
#    TRADE_CODE     CORP_NAME
# 0  3122S60004  上海元初国际物流有限公司

# %%
origin_country_df
# Out:
#                                                                                                                     COMPARISON  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579  [{"code_t":"发动机","qty1":"10","originCountry":"...
#
#                                                                                        ENTRY_ID  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579  224020221000000580
#
#                                                                                ENTRY_ID_COMPARE  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579  224020221000000579
#
#                                                                              OWNER_CODE  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579  3122S60004
#
#                                                                                OWNER_NAME  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579  上海元初国际物流有限公司
#
#                                                                             OWNER_CODE_SCC_COMPARE  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579     913100006929421297
#
#                                                                             OWNER_CODE_COMPARE  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579         3122S60004
#
#                                                                             OWNER_NAME_COMPARE  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579       上海元初国际物流有限公司
#
#                                                                                     CONSIGN_SCC  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579  91310000785178414H
#
#                                                                             CONSIGN_SCC_COMPARE  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579  91310000785178414H
#
#                                                                                CONSIGN_NAME  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579  施洁医疗技术（上海）有限公司
#
#                                                                             CONSIGN_NAME_COMPARE  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579       施洁医疗技术（上海）有限公司
#
#                                                                                                                          entry
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579  {"entryId":"224020221000000580","entryIdCompar...

# %%
entry_df
# Out:
#      CORP_CREDIT_CODE         BUSINESS_NO  \
# 0  913100006929421297  224020221000000580
#
#                                              CONTEXT  ID CUSTOMS_CODE  \
# 0  {"businessStartTime":"2022-06-15 18:17:05.2998...   0         2249
#
#   TYPE_FIRST TYPE_SECOND BUSINESS_TYPE ORDER_TYPE RESOLVE_STATUS RISK_LEVEL  \
# 0   GNYTJKYJ        BSWL            61      trade              0          3
#
#    TRADE_CODE     CORP_NAME
# 0  3122S60004  上海元初国际物流有限公司

# %%
Write_Oracle_Alarm().write_oracle('BD_RISK_CROSS_TRADE_WARAIN_TEMP', entry_df, org_code=None, alarm=None)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: SADeprecationWarning: The create_engine.convert_unicode parameter and corresponding dialect-level parameters are deprecated, and will be removed in a future release.  Modern DBAPIs support Python Unicode natively and this parameter is unnecessary.
# DW_CUS_RC/easipass
# 192.168.130.225:1521/pdbcusdev
# 2022-06-14 17:14:12.216 | INFO     | risk_models.config.read_config.read_func:read_oracle:73 - Read Table successfully! , Total read time spent 5.002s
#    ID    CORP_CREDIT_CODE         BUSINESS_NO  \
# 0   1  913100006929421297  224020221000000580
#
#                                              CONTEXT CUSTOMS_CODE TYPE_FIRST  \
# 0  {"businessStartTime":"2022-06-14 17:13:52.8205...         2249   GNYTJKYJ
#
#   TYPE_SECOND BUSINESS_TYPE ORDER_TYPE RESOLVE_STATUS RISK_LEVEL  TRADE_CODE  \
# 0        BSWL            61      trade              0          3  3122S60004
#
#       CORP_NAME
# 0  上海元初国际物流有限公司
# 2022-06-14 17:14:21.425 | INFO     | __main__:write_oracle:224 - Processing... Writing 1 rows into database
# 2022-06-14 17:14:24.071 | INFO     | __main__:write_oracle:230 - Insert data into BD_RISK_CROSS_TRADE_WARAIN_TEMP successfully! Total write time spent 16.86s

# %%
sql2 = '''SELECT t.BUSINESS_NO,
REPLACE(SUBSTR(t.CONTEXT ,23,10),'-','') AS date_1
FROM DW_CUS_RC.BD_RISK_CROSS_TRADE_WARAIN_TM t'''
ENTRY_ID_DF = Read_Oracle().read_oracle(sql=sql2, database='dbalarm')
ENTRY_ID_DF
list_temp= []
for i in range(ENTRY_ID_DF.shape[0]):
    if i not in list_temp:
        list_temp.append(ENTRY_ID_DF.iloc[i]['BUSINESS_NO'])
CORP_CREDIT_CODE_list_temp=list(set(list_temp))
CORP_CREDIT_CODE_list_temp
# Out:
# DW_CUS_RC/easipass
# 192.168.130.225:1521/pdbcusdev
# 2022-06-15 16:55:01.540 | INFO     | risk_models.config.read_config.read_func:read_oracle:73 - Read Table successfully! , Total read time spent 0.789s
# ['214020221000000512', '224020221000000413']

# %%
ENTRY_ID_DF
# Out:
#           BUSINESS_NO      DATE_1
# 0  214020221000000512  0307025504
# 1  224020221000000413  0307025503

# %%
entry_df
# Out:
#      CORP_CREDIT_CODE         BUSINESS_NO  \
# 0  913100006929421297  224020221000000580
#
#                                              CONTEXT  ID CUSTOMS_CODE  \
# 0  {"businessStartTime":"2022-06-15 16:52:55.7695...   0         2249
#
#   TYPE_FIRST TYPE_SECOND BUSINESS_TYPE ORDER_TYPE RESOLVE_STATUS RISK_LEVEL  \
# 0   GNYTJKYJ        BSWL            61      trade              0          3
#
#    TRADE_CODE     CORP_NAME
# 0  3122S60004  上海元初国际物流有限公司

# %%
# 清洗数据 去重
i_list = []
for i in range(entry_df.shape[0]):
    if (entry_df.iloc[i]['CORP_CREDIT_CODE'] in CORP_CREDIT_CODE_list_temp) and ((datetime.datetime.strptime(datetime.datetime.now().strftime('%Y-%m-%d'), "%Y-%m-%d")-datetime.datetime.strptime(entry_df.iloc[i]['CONTEXT'][22:32],'%Y-%m-%d')).days<180):
        i_list.append(i)
entry_df_distinct=entry_df.drop(labels=i_list)
entry_df_distinct
# Out:
#      CORP_CREDIT_CODE         BUSINESS_NO  \
# 0  913100006929421297  224020221000000580
#
#                                              CONTEXT  ID CUSTOMS_CODE  \
# 0  {"businessStartTime":"2022-06-15 16:52:55.7695...   0         2249
#
#   TYPE_FIRST TYPE_SECOND BUSINESS_TYPE ORDER_TYPE RESOLVE_STATUS RISK_LEVEL  \
# 0   GNYTJKYJ        BSWL            61      trade              0          3
#
#    TRADE_CODE     CORP_NAME
# 0  3122S60004  上海元初国际物流有限公司

# %%
sql_text = f'''
        select
        t1.ID,
        t1.ENTRY_ID,
        t1.I_E_PORT,
        t1.D_DATE,
        t1.CONSIGN_SCC,
        t1.CONSIGN_CODE,
        t1.CONSIGN_NAME,
        t1.OWNER_CODE_SCC as CORP_CREDIT_CODE,
        t1.ENTRY_ID as BUSINESS_NO,
        t1.OWNER_CODE,
        t1.OWNER_NAME,
        t1.TRADE_MODE,
        t1.G_NAME,
        t1.G_QTY,
        t1.ORIGIN_COUNTRY,
        t2.ENTRY_ID as ENTRY_ID_COMPARE,
        t2.I_E_PORT as I_E_PORT_COMPARE,
        t2.D_DATE as D_DATE_COMPARE,
        t2.OWNER_CODE_SCC as OWNER_CODE_SCC_COMPARE,
        t2.OWNER_CODE as OWNER_CODE_COMPARE,
        t2.OWNER_NAME as OWNER_NAME_COMPARE,
        t2.TRADE_MODE as TRADE_MODE_COMPARE,
        t2.CONSIGN_SCC AS CONSIGN_SCC_COMPARE,
        t2.CONSIGN_CODE AS CONSIGN_CODE_COMPARE,
        t2.CONSIGN_NAME AS CONSIGN_NAME_COMPARE,
        t2.G_NAME as G_NAME_COMPARE,
        t2.G_QTY as G_QTY_COMPARE,
        t2.ORIGIN_COUNTRY as ORIGIN_COUNTRY_COMPARE
        from DW_CUS_RC.BD_RISK_CROSS_TRADE_ORIGIN_CLN t1
        join DW_CUS_RC.BD_RISK_CROSS_TRADE_ORIGIN_CLN t2
        on t1.CONSIGN_SCC = t2.CONSIGN_SCC
        and t1.G_NAME = t2.G_NAME
        and t1.G_QTY = t2.G_QTY
        and t1.ORIGIN_COUNTRY != t2.ORIGIN_COUNTRY
        and t1.TRADE_MODE != t2.TRADE_MODE
                    '''
origin_country_df = Read_Oracle().read_oracle(sql=sql_text, database='dbalarm')
origin_country_df = origin_country_df.loc[origin_country_df['TRADE_MODE'] == '5034']
if origin_country_df is not None and len(origin_country_df) != 0:
    origin_country_df['COMPARISON'] = origin_country_df.apply(lambda x: deal_comparison_dic(x), axis=1)
    origin_country_df = origin_country_df.groupby(['ENTRY_ID', 'CORP_CREDIT_CODE', 'BUSINESS_NO', 'ENTRY_ID_COMPARE']).agg({'COMPARISON': 'sum', 'ENTRY_ID': 'first', 'ENTRY_ID_COMPARE': 'first', 'CORP_CREDIT_CODE': 'first', 'OWNER_CODE': 'first', 'OWNER_NAME': 'first', 'OWNER_CODE_SCC_COMPARE': 'first', 'OWNER_CODE_COMPARE': 'first', 'OWNER_NAME_COMPARE': 'first', 'CONSIGN_SCC': 'first', 'CONSIGN_SCC_COMPARE': 'first', 'CONSIGN_NAME': 'first', 'CONSIGN_NAME_COMPARE': 'first',})
    origin_country_df['COMPARISON'] = origin_country_df['COMPARISON'].map(lambda x: "[" + x[: -1] + "]")
    origin_country_df['entry'] = origin_country_df.apply(lambda x: deal_entry_dic(x), axis=1)
    origin_country_df.drop(columns=['CORP_CREDIT_CODE'], inplace=True)

    # entry_df = origin_country_df.groupby(['CORP_CREDIT_CODE', 'BUSINESS_NO']).agg({'entry': 'sum',  'OWNER_CODE': 'first', 'OWNER_NAME': 'first'})
    entry_df = origin_country_df.groupby(['CORP_CREDIT_CODE', 'BUSINESS_NO']).agg({'entry': 'first', 'OWNER_CODE': 'first', 'OWNER_NAME': 'first'})
    entry_df['entry'] = entry_df['entry'].map(lambda x: "[" + x[: -1] + "]")
    entry_df['CONTEXT'] = entry_df.apply(lambda x: deal_context_dic(x), axis=1)
    entry_df['ID'] = 0
    entry_df["CUSTOMS_CODE"] = "2249"
    entry_df["TYPE_FIRST"] = "GNYTJKYJ"
    entry_df["TYPE_SECOND"] = "BSWL"
    entry_df["BUSINESS_TYPE"] = "61"
    entry_df["ORDER_TYPE"] = "trade"
    entry_df["RESOLVE_STATUS"] = "0"
    entry_df["RISK_LEVEL"] = "3"
    # entry_df["LABEL"] = "一二线原产国预警"
    entry_df["TRADE_CODE"] = entry_df["OWNER_CODE"]
    entry_df["CORP_NAME"] = entry_df["OWNER_NAME"]
    entry_df.drop(columns=['entry', 'OWNER_NAME', 'OWNER_CODE'], inplace=True)
    entry_df = entry_df.reset_index()
    print(entry_df)
    # 对entry_df 去重
    sql2 = '''SELECT t.BUSINESS_NO,
            REPLACE(SUBSTR(t.CONTEXT ,23,10),'-','') AS date_1
            FROM DW_CUS_RC.BD_RISK_CROSS_TRADE_WARAIN_TM t'''
    ENTRY_ID_DF = Read_Oracle().read_oracle(sql=sql2, database='dbalarm')
    list_temp = []
    for i in range(ENTRY_ID_DF.shape[0]):
        if i not in list_temp:
            list_temp.append(ENTRY_ID_DF.iloc[i]['BUSINESS_NO'])
    CORP_CREDIT_CODE_list_temp = list(set(list_temp))
    # 提取CORP_CREDIT_CODE_list_temp 并去重

    # 清洗数据并去重 对针对30天内Bussiness_start_time数据去重
    i_list = []
    for i in range(entry_df.shape[0]):
        if (entry_df.iloc[i]['BUSINESS_NO'] in CORP_CREDIT_CODE_list_temp)and ((datetime.datetime.strptime(datetime.datetime.now().strftime('%Y-%m-%d'),
                                                                                                           "%Y-%m-%d") - datetime.datetime.strptime(
            entry_df.iloc[i]['CONTEXT'][22:32], '%Y-%m-%d')).days < 180):
            i_list.append(i)
    entry_df_distinct = entry_df.drop(labels=i_list)
    # 获得去重后的DataFrame, entry_df_distinct
# Out:
# DW_CUS_RC/easipass
# 192.168.130.225:1521/pdbcusdev
# 2022-06-15 23:08:51.464 | INFO     | risk_models.config.read_config.read_func:read_oracle:73 - Read Table successfully! , Total read time spent 1.727s
#      CORP_CREDIT_CODE         BUSINESS_NO  \
# 0  913100006929421297  214020221000000581
# 1  913100006929421297  224020221000000580
#
#                                              CONTEXT  ID CUSTOMS_CODE  \
# 0  {"businessStartTime":"2022-06-15 23:08:51.5097...   0         2249
# 1  {"businessStartTime":"2022-06-15 23:08:51.5097...   0         2249
#
#   TYPE_FIRST TYPE_SECOND BUSINESS_TYPE ORDER_TYPE RESOLVE_STATUS RISK_LEVEL  \
# 0   GNYTJKYJ        BSWL            61      trade              0          3
# 1   GNYTJKYJ        BSWL            61      trade              0          3
#
#    TRADE_CODE     CORP_NAME
# 0  3122S60004  上海元初国际物流有限公司
# 1  3122S60004  上海元初国际物流有限公司
# DW_CUS_RC/easipass
# 192.168.130.225:1521/pdbcusdev
# 2022-06-15 23:08:52.151 | INFO     | risk_models.config.read_config.read_func:read_oracle:73 - Read Table successfully! , Total read time spent 0.625s

# %%
entry_df_distinct
# Out:
# Empty DataFrame
# Columns: [CORP_CREDIT_CODE, BUSINESS_NO, CONTEXT, ID, CUSTOMS_CODE, TYPE_FIRST, TYPE_SECOND, BUSINESS_TYPE, ORDER_TYPE, RESOLVE_STATUS, RISK_LEVEL, TRADE_CODE, CORP_NAME]
# Index: []

# %%
print(entry_df_distinct.shape[0])
# Out:
# 1

# %%
entry_df_distinct1=entry_df_distinct.drop(labels=[0])

# %%
entry_df_distinct1
# Out:
# Empty DataFrame
# Columns: [CORP_CREDIT_CODE, BUSINESS_NO, CONTEXT, ID, CUSTOMS_CODE, TYPE_FIRST, TYPE_SECOND, BUSINESS_TYPE, ORDER_TYPE, RESOLVE_STATUS, RISK_LEVEL, TRADE_CODE, CORP_NAME]
# Index: []

# %%
print(entry_df_distinct1.size)
# Out:
# 0

# %%
entry_df['CREATE_TIME']=datetime.datetime.now()
entry_df['UPDATE_TIME']=datetime.datetime.now()
entry_df
# Out:
#      CORP_CREDIT_CODE         BUSINESS_NO  \
# 0  913100006929421297  214020221000000581
# 1  913100006929421297  224020221000000580
#
#                                              CONTEXT  ID CUSTOMS_CODE  \
# 0  {"businessStartTime":"2022-06-15 23:03:58.9382...   0         2249
# 1  {"businessStartTime":"2022-06-15 23:03:58.9382...   0         2249
#
#   TYPE_FIRST TYPE_SECOND BUSINESS_TYPE ORDER_TYPE RESOLVE_STATUS RISK_LEVEL  \
# 0   GNYTJKYJ        BSWL            61      trade              0          3
# 1   GNYTJKYJ        BSWL            61      trade              0          3
#
#    TRADE_CODE     CORP_NAME                CREATE_TIME  \
# 0  3122S60004  上海元初国际物流有限公司 2022-06-15 23:04:31.057622
# 1  3122S60004  上海元初国际物流有限公司 2022-06-15 23:04:31.057622
#
#                  UPDATE_TIME
# 0 2022-06-15 23:04:31.058618
# 1 2022-06-15 23:04:31.058618

# %%
# 写入Oracle 数据库
Write_Oracle_Alarm().write_oracle('BD_RISK_CROSS_TRADE_WARAIN_TM', entry_df, org_code=None,
                                  alarm=None)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: SADeprecationWarning: The create_engine.convert_unicode parameter and corresponding dialect-level parameters are deprecated, and will be removed in a future release.  Modern DBAPIs support Python Unicode natively and this parameter is unnecessary.
# DW_CUS_RC/easipass
# 192.168.130.225:1521/pdbcusdev
# 2022-06-15 23:11:37.853 | INFO     | risk_models.config.read_config.read_func:read_oracle:73 - Read Table successfully! , Total read time spent 0.886s
#    ID    CORP_CREDIT_CODE         BUSINESS_NO  \
# 0  11  913100006929421297  214020221000000581
# 1  12  913100006929421297  224020221000000580
#
#                                              CONTEXT CUSTOMS_CODE TYPE_FIRST  \
# 0  {"businessStartTime":"2022-06-15 23:08:51.5097...         2249   GNYTJKYJ
# 1  {"businessStartTime":"2022-06-15 23:08:51.5097...         2249   GNYTJKYJ
#
#   TYPE_SECOND BUSINESS_TYPE ORDER_TYPE RESOLVE_STATUS RISK_LEVEL  TRADE_CODE  \
# 0        BSWL            61      trade              0          3  3122S60004
# 1        BSWL            61      trade              0          3  3122S60004
#
#       CORP_NAME
# 0  上海元初国际物流有限公司
# 1  上海元初国际物流有限公司
# 2022-06-15 23:11:39.354 | INFO     | __main__:write_oracle:224 - Processing... Writing 2 rows into database
# 2022-06-15 23:11:39.588 | INFO     | __main__:write_oracle:230 - Insert data into BD_RISK_CROSS_TRADE_WARAIN_TM successfully! Total write time spent 2.622s

# %%
origin_country_df = Read_Oracle().read_oracle(sql=sql_text, database='dbalarm')
origin_country_df = origin_country_df.loc[origin_country_df['TRADE_MODE'] == '5034']
# Out:
# DW_CUS_RC/easipass
# 192.168.130.225:1521/pdbcusdev
# 2022-06-15 20:44:25.846 | INFO     | risk_models.config.read_config.read_func:read_oracle:73 - Read Table successfully! , Total read time spent 1.124s

# %%
origin_country_df['COMPARISON'] = origin_country_df.apply(lambda x: deal_comparison_dic(x), axis=1)

# %%
origin_country_df
# Out:
#     ID            ENTRY_ID I_E_PORT    D_DATE         CONSIGN_SCC  \
# 0   15  224020221000000580     2249  20220601  91310000785178414H
# 1   21  224020221000000580     2249  20220601  91310000785178414H
# 2    4  224020221000000580     2249  20220601  91310000785178414H
# 6   13  224020221000000580     2249  20220601  91310000785178414H
# 7   19  224020221000000580     2249  20220601  91310000785178414H
# 8    2  224020221000000580     2249  20220601  91310000785178414H
# 15  16  214020221000000581     2249  20220601  91310000785178414H
# 16  11  214020221000000581     2249  20220601  91310000785178414H
# 17   5  224020221000000580     2249  20220601  91310000785178414H
# 18  15  224020221000000580     2249  20220601  91310000785178414H
# 19  21  224020221000000580     2249  20220601  91310000785178414H
# 20   4  224020221000000580     2249  20220601  91310000785178414H
# 24  13  224020221000000580     2249  20220601  91310000785178414H
# 25  19  224020221000000580     2249  20220601  91310000785178414H
# 26   2  224020221000000580     2249  20220601  91310000785178414H
# 30  16  214020221000000581     2249  20220601  91310000785178414H
# 31  11  214020221000000581     2249  20220601  91310000785178414H
# 32   5  224020221000000580     2249  20220601  91310000785178414H
# 36  15  224020221000000580     2249  20220601  91310000785178414H
# 37  21  224020221000000580     2249  20220601  91310000785178414H
# 38   4  224020221000000580     2249  20220601  91310000785178414H
# 42  13  224020221000000580     2249  20220601  91310000785178414H
# 43  19  224020221000000580     2249  20220601  91310000785178414H
# 44   2  224020221000000580     2249  20220601  91310000785178414H
# 51  16  214020221000000581     2249  20220601  91310000785178414H
# 52  11  214020221000000581     2249  20220601  91310000785178414H
# 53   5  224020221000000580     2249  20220601  91310000785178414H
#
#    CONSIGN_CODE    CONSIGN_NAME    CORP_CREDIT_CODE         BUSINESS_NO  \
# 0             2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 1             2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 2             2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 6             2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 7             2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 8             2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 15            2  施洁医疗技术（上海）有限公司  913100006929421297  214020221000000581
# 16            2  施洁医疗技术（上海）有限公司  913100006929421297  214020221000000581
# 17            2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 18            2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 19            2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 20            2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 24            2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 25            2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 26            2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 30            2  施洁医疗技术（上海）有限公司  913100006929421297  214020221000000581
# 31            2  施洁医疗技术（上海）有限公司  913100006929421297  214020221000000581
# 32            2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 36            2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 37            2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 38            2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 42            2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 43            2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 44            2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
# 51            2  施洁医疗技术（上海）有限公司  913100006929421297  214020221000000581
# 52            2  施洁医疗技术（上海）有限公司  913100006929421297  214020221000000581
# 53            2  施洁医疗技术（上海）有限公司  913100006929421297  224020221000000580
#
#     OWNER_CODE    OWNER_NAME TRADE_MODE G_NAME G_QTY ORIGIN_COUNTRY  \
# 0   3122S60004  上海元初国际物流有限公司       5034   发动机3    10            KUW
# 1   3122S60004  上海元初国际物流有限公司       5034   发动机3    10            KUW
# 2   3122S60004  上海元初国际物流有限公司       5034   发动机3    10            KUW
# 6   3122S60004  上海元初国际物流有限公司       5034    发动机    10            CAN
# 7   3122S60004  上海元初国际物流有限公司       5034    发动机    10            CAN
# 8   3122S60004  上海元初国际物流有限公司       5034    发动机    10            CAN
# 15  3122S60004  上海元初国际物流有限公司       5034   发动机2    10            BOT
# 16  3122S60004  上海元初国际物流有限公司       5034   发动机2    10            BOT
# 17  3122S60004  上海元初国际物流有限公司       5034   发动机2    10            BOT
# 18  3122S60004  上海元初国际物流有限公司       5034   发动机3    10            KUW
# 19  3122S60004  上海元初国际物流有限公司       5034   发动机3    10            KUW
# 20  3122S60004  上海元初国际物流有限公司       5034   发动机3    10            KUW
# 24  3122S60004  上海元初国际物流有限公司       5034    发动机    10            CAN
# 25  3122S60004  上海元初国际物流有限公司       5034    发动机    10            CAN
# 26  3122S60004  上海元初国际物流有限公司       5034    发动机    10            CAN
# 30  3122S60004  上海元初国际物流有限公司       5034   发动机2    10            BOT
# 31  3122S60004  上海元初国际物流有限公司       5034   发动机2    10            BOT
# 32  3122S60004  上海元初国际物流有限公司       5034   发动机2    10            BOT
# 36  3122S60004  上海元初国际物流有限公司       5034   发动机3    10            KUW
# 37  3122S60004  上海元初国际物流有限公司       5034   发动机3    10            KUW
# 38  3122S60004  上海元初国际物流有限公司       5034   发动机3    10            KUW
# 42  3122S60004  上海元初国际物流有限公司       5034    发动机    10            CAN
# 43  3122S60004  上海元初国际物流有限公司       5034    发动机    10            CAN
# 44  3122S60004  上海元初国际物流有限公司       5034    发动机    10            CAN
# 51  3122S60004  上海元初国际物流有限公司       5034   发动机2    10            BOT
# 52  3122S60004  上海元初国际物流有限公司       5034   发动机2    10            BOT
# 53  3122S60004  上海元初国际物流有限公司       5034   发动机2    10            BOT
#
#       ENTRY_ID_COMPARE I_E_PORT_COMPARE D_DATE_COMPARE OWNER_CODE_SCC_COMPARE  \
# 0   224020221000000579             2249       20220601     913100006929421297
# 1   224020221000000579             2249       20220601     913100006929421297
# 2   224020221000000579             2249       20220601     913100006929421297
# 6   224020221000000579             2249       20220601     913100006929421297
# 7   224020221000000579             2249       20220601     913100006929421297
# 8   224020221000000579             2249       20220601     913100006929421297
# 15  224020221000000579             2249       20220601     913100006929421297
# 16  224020221000000579             2249       20220601     913100006929421297
# 17  224020221000000579             2249       20220601     913100006929421297
# 18  224020221000000579             2249       20220601     913100006929421297
# 19  224020221000000579             2249       20220601     913100006929421297
# 20  224020221000000579             2249       20220601     913100006929421297
# 24  224020221000000579             2249       20220601     913100006929421297
# 25  224020221000000579             2249       20220601     913100006929421297
# 26  224020221000000579             2249       20220601     913100006929421297
# 30  224020221000000579             2249       20220601     913100006929421297
# 31  224020221000000579             2249       20220601     913100006929421297
# 32  224020221000000579             2249       20220601     913100006929421297
# 36  224020221000000579             2249       20220601     913100006929421297
# 37  224020221000000579             2249       20220601     913100006929421297
# 38  224020221000000579             2249       20220601     913100006929421297
# 42  224020221000000579             2249       20220601     913100006929421297
# 43  224020221000000579             2249       20220601     913100006929421297
# 44  224020221000000579             2249       20220601     913100006929421297
# 51  224020221000000579             2249       20220601     913100006929421297
# 52  224020221000000579             2249       20220601     913100006929421297
# 53  224020221000000579             2249       20220601     913100006929421297
#
#    OWNER_CODE_COMPARE OWNER_NAME_COMPARE TRADE_MODE_COMPARE  \
# 0          3122S60004       上海元初国际物流有限公司               0110
# 1          3122S60004       上海元初国际物流有限公司               0110
# 2          3122S60004       上海元初国际物流有限公司               0110
# 6          3122S60004       上海元初国际物流有限公司               0110
# 7          3122S60004       上海元初国际物流有限公司               0110
# 8          3122S60004       上海元初国际物流有限公司               0110
# 15         3122S60004       上海元初国际物流有限公司               0110
# 16         3122S60004       上海元初国际物流有限公司               0110
# 17         3122S60004       上海元初国际物流有限公司               0110
# 18         3122S60004       上海元初国际物流有限公司               0110
# 19         3122S60004       上海元初国际物流有限公司               0110
# 20         3122S60004       上海元初国际物流有限公司               0110
# 24         3122S60004       上海元初国际物流有限公司               0110
# 25         3122S60004       上海元初国际物流有限公司               0110
# 26         3122S60004       上海元初国际物流有限公司               0110
# 30         3122S60004       上海元初国际物流有限公司               0110
# 31         3122S60004       上海元初国际物流有限公司               0110
# 32         3122S60004       上海元初国际物流有限公司               0110
# 36         3122S60004       上海元初国际物流有限公司               0110
# 37         3122S60004       上海元初国际物流有限公司               0110
# 38         3122S60004       上海元初国际物流有限公司               0110
# 42         3122S60004       上海元初国际物流有限公司               0110
# 43         3122S60004       上海元初国际物流有限公司               0110
# 44         3122S60004       上海元初国际物流有限公司               0110
# 51         3122S60004       上海元初国际物流有限公司               0110
# 52         3122S60004       上海元初国际物流有限公司               0110
# 53         3122S60004       上海元初国际物流有限公司               0110
#
#    CONSIGN_SCC_COMPARE CONSIGN_CODE_COMPARE CONSIGN_NAME_COMPARE  \
# 0   91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 1   91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 2   91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 6   91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 7   91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 8   91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 15  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 16  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 17  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 18  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 19  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 20  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 24  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 25  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 26  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 30  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 31  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 32  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 36  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 37  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 38  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 42  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 43  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 44  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 51  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 52  91310000785178414H                    2       施洁医疗技术（上海）有限公司
# 53  91310000785178414H                    2       施洁医疗技术（上海）有限公司
#
#    G_NAME_COMPARE G_QTY_COMPARE ORIGIN_COUNTRY_COMPARE  \
# 0            发动机3            10                    USA
# 1            发动机3            10                    USA
# 2            发动机3            10                    USA
# 6             发动机            10                    BEN
# 7             发动机            10                    BEN
# 8             发动机            10                    BEN
# 15           发动机2            10                    ANG
# 16           发动机2            10                    ANG
# 17           发动机2            10                    ANG
# 18           发动机3            10                    USA
# 19           发动机3            10                    USA
# 20           发动机3            10                    USA
# 24            发动机            10                    BEN
# 25            发动机            10                    BEN
# 26            发动机            10                    BEN
# 30           发动机2            10                    ANG
# 31           发动机2            10                    ANG
# 32           发动机2            10                    ANG
# 36           发动机3            10                    USA
# 37           发动机3            10                    USA
# 38           发动机3            10                    USA
# 42            发动机            10                    BEN
# 43            发动机            10                    BEN
# 44            发动机            10                    BEN
# 51           发动机2            10                    ANG
# 52           发动机2            10                    ANG
# 53           发动机2            10                    ANG
#
#                                            COMPARISON
# 0   {"code_t":"发动机3","qty1":"10","originCountry":"...
# 1   {"code_t":"发动机3","qty1":"10","originCountry":"...
# 2   {"code_t":"发动机3","qty1":"10","originCountry":"...
# 6   {"code_t":"发动机","qty1":"10","originCountry":"C...
# 7   {"code_t":"发动机","qty1":"10","originCountry":"C...
# 8   {"code_t":"发动机","qty1":"10","originCountry":"C...
# 15  {"code_t":"发动机2","qty1":"10","originCountry":"...
# 16  {"code_t":"发动机2","qty1":"10","originCountry":"...
# 17  {"code_t":"发动机2","qty1":"10","originCountry":"...
# 18  {"code_t":"发动机3","qty1":"10","originCountry":"...
# 19  {"code_t":"发动机3","qty1":"10","originCountry":"...
# 20  {"code_t":"发动机3","qty1":"10","originCountry":"...
# 24  {"code_t":"发动机","qty1":"10","originCountry":"C...
# 25  {"code_t":"发动机","qty1":"10","originCountry":"C...
# 26  {"code_t":"发动机","qty1":"10","originCountry":"C...
# 30  {"code_t":"发动机2","qty1":"10","originCountry":"...
# 31  {"code_t":"发动机2","qty1":"10","originCountry":"...
# 32  {"code_t":"发动机2","qty1":"10","originCountry":"...
# 36  {"code_t":"发动机3","qty1":"10","originCountry":"...
# 37  {"code_t":"发动机3","qty1":"10","originCountry":"...
# 38  {"code_t":"发动机3","qty1":"10","originCountry":"...
# 42  {"code_t":"发动机","qty1":"10","originCountry":"C...
# 43  {"code_t":"发动机","qty1":"10","originCountry":"C...
# 44  {"code_t":"发动机","qty1":"10","originCountry":"C...
# 51  {"code_t":"发动机2","qty1":"10","originCountry":"...
# 52  {"code_t":"发动机2","qty1":"10","originCountry":"...
# 53  {"code_t":"发动机2","qty1":"10","originCountry":"...

# %%
origin_country_df
# Out:
#                                                                                                                     COMPARISON  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 214020221000000581 913100006929421297 214020221000000581 224020221000000579  [{"code_t":"发动机2","qty1":"10","originCountry":...
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579  [{"code_t":"发动机3","qty1":"10","originCountry":...
#
#                                                                                        ENTRY_ID  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 214020221000000581 913100006929421297 214020221000000581 224020221000000579  214020221000000581
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579  224020221000000580
#
#                                                                                ENTRY_ID_COMPARE  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 214020221000000581 913100006929421297 214020221000000581 224020221000000579  224020221000000579
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579  224020221000000579
#
#                                                                              OWNER_CODE  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 214020221000000581 913100006929421297 214020221000000581 224020221000000579  3122S60004
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579  3122S60004
#
#                                                                                OWNER_NAME  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 214020221000000581 913100006929421297 214020221000000581 224020221000000579  上海元初国际物流有限公司
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579  上海元初国际物流有限公司
#
#                                                                             OWNER_CODE_SCC_COMPARE  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 214020221000000581 913100006929421297 214020221000000581 224020221000000579     913100006929421297
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579     913100006929421297
#
#                                                                             OWNER_CODE_COMPARE  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 214020221000000581 913100006929421297 214020221000000581 224020221000000579         3122S60004
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579         3122S60004
#
#                                                                             OWNER_NAME_COMPARE  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 214020221000000581 913100006929421297 214020221000000581 224020221000000579       上海元初国际物流有限公司
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579       上海元初国际物流有限公司
#
#                                                                                     CONSIGN_SCC  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 214020221000000581 913100006929421297 214020221000000581 224020221000000579  91310000785178414H
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579  91310000785178414H
#
#                                                                             CONSIGN_SCC_COMPARE  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 214020221000000581 913100006929421297 214020221000000581 224020221000000579  91310000785178414H
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579  91310000785178414H
#
#                                                                                CONSIGN_NAME  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 214020221000000581 913100006929421297 214020221000000581 224020221000000579  施洁医疗技术（上海）有限公司
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579  施洁医疗技术（上海）有限公司
#
#                                                                             CONSIGN_NAME_COMPARE  \
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 214020221000000581 913100006929421297 214020221000000581 224020221000000579       施洁医疗技术（上海）有限公司
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579       施洁医疗技术（上海）有限公司
#
#                                                                                                                          entry
# ENTRY_ID           CORP_CREDIT_CODE   BUSINESS_NO        ENTRY_ID_COMPARE
# 214020221000000581 913100006929421297 214020221000000581 224020221000000579  {"entryId":"214020221000000581","entryIdCompar...
# 224020221000000580 913100006929421297 224020221000000580 224020221000000579  {"entryId":"224020221000000580","entryIdCompar...

# %%
deal_comparison_dic(origin_country_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'G_NAME'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-084e38d240f6> in <module>
# ----> 1 deal_comparison_dic(origin_country_df)
#
# <ipython-input-1-de59fe972a01> in deal_comparison_dic(df)
#     211     temp_dic = {}
#     212     str = "{"
# --> 213     temp_dic['code_t'] = df['G_NAME']
#     214     temp_dic['qty1'] = df['G_QTY']
#     215     temp_dic['originCountry'] = df['ORIGIN_COUNTRY']
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: 'G_NAME'

# %%
import  json
entry_df['CONTEXT'][0]
# json1 = json.loads(entry_df['CONTEXT'][0])
# json1
# Out:
# '{"businessStartTime":"2022-06-15 22:11:26.448034","businessEndTime":"2022-06-15 22:11:26.448034","entry":"[{"entryId":"214020221000000581","entryIdCompare":"224020221000000579","comparison":"[{"code_t":"发动机2","qty1":"10","originCountry":"BOT","codeTCompare":"发动机2","qty1Compare":"10","originCountryCompare":"ANG"},{"code_t":"发动机2","qty1":"10","originCountry":"BOT","codeTCompare":"发动机2","qty1Compare":"10","originCountryCompare":"ANG"},{"code_t":"发动机2","qty1":"10","originCountry":"BOT","codeTCompare":"发动机2","qty1Compare":"10","originCountryCompare":"ANG"},{"code_t":"发动机2","qty1":"10","originCountry":"BOT","codeTCompare":"发动机2","qty1Compare":"10","originCountryCompare":"ANG"},{"code_t":"发动机2","qty1":"10","originCountry":"BOT","codeTCompare":"发动机2","qty1Compare":"10","originCountryCompare":"ANG"},{"code_t":"发动机2","qty1":"10","originCountry":"BOT","codeTCompare":"发动机2","qty1Compare":"10","originCountryCompare":"ANG"}]","ownerCode":"91310000785178414H","ownerName":"施洁医疗技术（上海）有限公司","ownerCodeCompare":"91310000785178414H","ownerNameCompare":"施洁医疗技术（上海）有限公司"}]"}'

# %%
entry_df['CONTEXT'][0].replace('"entry":"[{"', '"entry":[{"').replace('"comparison":"[{"code_t','"comparison":[{"code_t').replace(']","ownerCode":','],"ownerCode":').replace('}]"}','}]}')
# Out:
# '{"businessStartTime":"2022-06-15 22:11:26.448034","businessEndTime":"2022-06-15 22:11:26.448034","entry":[{"entryId":"214020221000000581","entryIdCompare":"224020221000000579","comparison":[{"code_t":"发动机2","qty1":"10","originCountry":"BOT","codeTCompare":"发动机2","qty1Compare":"10","originCountryCompare":"ANG"},{"code_t":"发动机2","qty1":"10","originCountry":"BOT","codeTCompare":"发动机2","qty1Compare":"10","originCountryCompare":"ANG"},{"code_t":"发动机2","qty1":"10","originCountry":"BOT","codeTCompare":"发动机2","qty1Compare":"10","originCountryCompare":"ANG"},{"code_t":"发动机2","qty1":"10","originCountry":"BOT","codeTCompare":"发动机2","qty1Compare":"10","originCountryCompare":"ANG"},{"code_t":"发动机2","qty1":"10","originCountry":"BOT","codeTCompare":"发动机2","qty1Compare":"10","originCountryCompare":"ANG"},{"code_t":"发动机2","qty1":"10","originCountry":"BOT","codeTCompare":"发动机2","qty1Compare":"10","originCountryCompare":"ANG"}],"ownerCode":"91310000785178414H","ownerName":"施洁医疗技术（上海）有限公司","ownerCodeCompare":"91310000785178414H","ownerNameCompare":"施洁医疗技术（上海）有限公司"}]}'

# %%
json.loads(entry_df['CONTEXT'][1].replace('"entry":"[{"', '"entry":[{"').replace('"comparison":"[{"code_t','"comparison":[{"code_t').replace(']","ownerCode":','],"ownerCode":').replace('}]"}','}]}'))
# Out:
# {'businessStartTime': '2022-06-15 23:03:58.938211',
#  'businessEndTime': '2022-06-15 23:03:58.938211',
#  'entry': [{'entryId': '224020221000000580',
#    'entryIdCompare': '224020221000000579',
#    'comparison': [{'code_t': '发动机3',
#      'qty1': '10',
#      'originCountry': 'KUW',
#      'codeTCompare': '发动机3',
#      'qty1Compare': '10',
#      'originCountryCompare': 'USA'},
#     {'code_t': '发动机3',
#      'qty1': '10',
#      'originCountry': 'KUW',
#      'codeTCompare': '发动机3',
#      'qty1Compare': '10',
#      'originCountryCompare': 'USA'},
#     {'code_t': '发动机3',
#      'qty1': '10',
#      'originCountry': 'KUW',
#      'codeTCompare': '发动机3',
#      'qty1Compare': '10',
#      'originCountryCompare': 'USA'},
#     {'code_t': '发动机',
#      'qty1': '10',
#      'originCountry': 'CAN',
#      'codeTCompare': '发动机',
#      'qty1Compare': '10',
#      'originCountryCompare': 'BEN'},
#     {'code_t': '发动机',
#      'qty1': '10',
#      'originCountry': 'CAN',
#      'codeTCompare': '发动机',
#      'qty1Compare': '10',
#      'originCountryCompare': 'BEN'},
#     {'code_t': '发动机',
#      'qty1': '10',
#      'originCountry': 'CAN',
#      'codeTCompare': '发动机',
#      'qty1Compare': '10',
#      'originCountryCompare': 'BEN'},
#     {'code_t': '发动机2',
#      'qty1': '10',
#      'originCountry': 'BOT',
#      'codeTCompare': '发动机2',
#      'qty1Compare': '10',
#      'originCountryCompare': 'ANG'},
#     {'code_t': '发动机3',
#      'qty1': '10',
#      'originCountry': 'KUW',
#      'codeTCompare': '发动机3',
#      'qty1Compare': '10',
#      'originCountryCompare': 'USA'},
#     {'code_t': '发动机3',
#      'qty1': '10',
#      'originCountry': 'KUW',
#      'codeTCompare': '发动机3',
#      'qty1Compare': '10',
#      'originCountryCompare': 'USA'},
#     {'code_t': '发动机3',
#      'qty1': '10',
#      'originCountry': 'KUW',
#      'codeTCompare': '发动机3',
#      'qty1Compare': '10',
#      'originCountryCompare': 'USA'},
#     {'code_t': '发动机',
#      'qty1': '10',
#      'originCountry': 'CAN',
#      'codeTCompare': '发动机',
#      'qty1Compare': '10',
#      'originCountryCompare': 'BEN'},
#     {'code_t': '发动机',
#      'qty1': '10',
#      'originCountry': 'CAN',
#      'codeTCompare': '发动机',
#      'qty1Compare': '10',
#      'originCountryCompare': 'BEN'},
#     {'code_t': '发动机',
#      'qty1': '10',
#      'originCountry': 'CAN',
#      'codeTCompare': '发动机',
#      'qty1Compare': '10',
#      'originCountryCompare': 'BEN'},
#     {'code_t': '发动机2',
#      'qty1': '10',
#      'originCountry': 'BOT',
#      'codeTCompare': '发动机2',
#      'qty1Compare': '10',
#      'originCountryCompare': 'ANG'},
#     {'code_t': '发动机3',
#      'qty1': '10',
#      'originCountry': 'KUW',
#      'codeTCompare': '发动机3',
#      'qty1Compare': '10',
#      'originCountryCompare': 'USA'},
#     {'code_t': '发动机3',
#      'qty1': '10',
#      'originCountry': 'KUW',
#      'codeTCompare': '发动机3',
#      'qty1Compare': '10',
#      'originCountryCompare': 'USA'},
#     {'code_t': '发动机3',
#      'qty1': '10',
#      'originCountry': 'KUW',
#      'codeTCompare': '发动机3',
#      'qty1Compare': '10',
#      'originCountryCompare': 'USA'},
#     {'code_t': '发动机',
#      'qty1': '10',
#      'originCountry': 'CAN',
#      'codeTCompare': '发动机',
#      'qty1Compare': '10',
#      'originCountryCompare': 'BEN'},
#     {'code_t': '发动机',
#      'qty1': '10',
#      'originCountry': 'CAN',
#      'codeTCompare': '发动机',
#      'qty1Compare': '10',
#      'originCountryCompare': 'BEN'},
#     {'code_t': '发动机',
#      'qty1': '10',
#      'originCountry': 'CAN',
#      'codeTCompare': '发动机',
#      'qty1Compare': '10',
#      'originCountryCompare': 'BEN'},
#     {'code_t': '发动机2',
#      'qty1': '10',
#      'originCountry': 'BOT',
#      'codeTCompare': '发动机2',
#      'qty1Compare': '10',
#      'originCountryCompare': 'ANG'}],
#    'ownerCode': '91310000785178414H',
#    'ownerName': '施洁医疗技术（上海）有限公司',
#    'ownerCodeCompare': '91310000785178414H',
#    'ownerNameCompare': '施洁医疗技术（上海）有限公司'}]}

# %%
json.loads(entry_df['CONTEXT'][1])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-68-1597fc76c556> in <module>
# ----> 1 json.loads(entry_df['CONTEXT'][1])
#
# C:\ProgramData\Anaconda3\lib\json\__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# C:\ProgramData\Anaconda3\lib\json\decoder.py in raw_decode(self, s, idx)
#     351         """
#     352         try:
# --> 353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
#     355             raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting ',' delimiter: line 1 column 110 (char 109)

# %%
entry_df
# Out:
#      CORP_CREDIT_CODE         BUSINESS_NO  \
# 0  913100006929421297  214020221000000581
# 1  913100006929421297  224020221000000580
#
#                                              CONTEXT  ID CUSTOMS_CODE  \
# 0  {"businessStartTime":"2022-06-15 23:08:51.5097...   0         2249
# 1  {"businessStartTime":"2022-06-15 23:08:51.5097...   0         2249
#
#   TYPE_FIRST TYPE_SECOND BUSINESS_TYPE ORDER_TYPE RESOLVE_STATUS RISK_LEVEL  \
# 0   GNYTJKYJ        BSWL            61      trade              0          3
# 1   GNYTJKYJ        BSWL            61      trade              0          3
#
#    TRADE_CODE     CORP_NAME
# 0  3122S60004  上海元初国际物流有限公司
# 1  3122S60004  上海元初国际物流有限公司

# %%
# 转换为标准的json 格式
for i in range(0,entry_df.shape[0]):
    entry_df['CONTEXT'][i]=entry_df['CONTEXT'][i].replace('"entry":"[{"', '"entry":[{"').replace('"comparison":"[{"code_t','"comparison":[{"code_t').replace(']","ownerCode":','],"ownerCode":').replace('}]"}','}]}')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
entry_df
# Out:
#      CORP_CREDIT_CODE         BUSINESS_NO  \
# 0  913100006929421297  214020221000000581
# 1  913100006929421297  224020221000000580
#
#                                              CONTEXT  ID CUSTOMS_CODE  \
# 0  {"businessStartTime":"2022-06-15 23:08:51.5097...   0         2249
# 1  {"businessStartTime":"2022-06-15 23:08:51.5097...   0         2249
#
#   TYPE_FIRST TYPE_SECOND BUSINESS_TYPE ORDER_TYPE RESOLVE_STATUS RISK_LEVEL  \
# 0   GNYTJKYJ        BSWL            61      trade              0          3
# 1   GNYTJKYJ        BSWL            61      trade              0          3
#
#    TRADE_CODE     CORP_NAME
# 0  3122S60004  上海元初国际物流有限公司
# 1  3122S60004  上海元初国际物流有限公司

# %%
json.loads(entry_df['CONTEXT'][1])
# Out:
# {'businessStartTime': '2022-06-15 23:08:51.509723',
#  'businessEndTime': '2022-06-15 23:08:51.509723',
#  'entry': [{'entryId': '224020221000000580',
#    'entryIdCompare': '224020221000000579',
#    'comparison': [{'code_t': '发动机3',
#      'qty1': '10',
#      'originCountry': 'KUW',
#      'codeTCompare': '发动机3',
#      'qty1Compare': '10',
#      'originCountryCompare': 'USA'},
#     {'code_t': '发动机3',
#      'qty1': '10',
#      'originCountry': 'KUW',
#      'codeTCompare': '发动机3',
#      'qty1Compare': '10',
#      'originCountryCompare': 'USA'},
#     {'code_t': '发动机3',
#      'qty1': '10',
#      'originCountry': 'KUW',
#      'codeTCompare': '发动机3',
#      'qty1Compare': '10',
#      'originCountryCompare': 'USA'},
#     {'code_t': '发动机',
#      'qty1': '10',
#      'originCountry': 'CAN',
#      'codeTCompare': '发动机',
#      'qty1Compare': '10',
#      'originCountryCompare': 'BEN'},
#     {'code_t': '发动机',
#      'qty1': '10',
#      'originCountry': 'CAN',
#      'codeTCompare': '发动机',
#      'qty1Compare': '10',
#      'originCountryCompare': 'BEN'},
#     {'code_t': '发动机',
#      'qty1': '10',
#      'originCountry': 'CAN',
#      'codeTCompare': '发动机',
#      'qty1Compare': '10',
#      'originCountryCompare': 'BEN'},
#     {'code_t': '发动机2',
#      'qty1': '10',
#      'originCountry': 'BOT',
#      'codeTCompare': '发动机2',
#      'qty1Compare': '10',
#      'originCountryCompare': 'ANG'},
#     {'code_t': '发动机3',
#      'qty1': '10',
#      'originCountry': 'KUW',
#      'codeTCompare': '发动机3',
#      'qty1Compare': '10',
#      'originCountryCompare': 'USA'},
#     {'code_t': '发动机3',
#      'qty1': '10',
#      'originCountry': 'KUW',
#      'codeTCompare': '发动机3',
#      'qty1Compare': '10',
#      'originCountryCompare': 'USA'},
#     {'code_t': '发动机3',
#      'qty1': '10',
#      'originCountry': 'KUW',
#      'codeTCompare': '发动机3',
#      'qty1Compare': '10',
#      'originCountryCompare': 'USA'},
#     {'code_t': '发动机',
#      'qty1': '10',
#      'originCountry': 'CAN',
#      'codeTCompare': '发动机',
#      'qty1Compare': '10',
#      'originCountryCompare': 'BEN'},
#     {'code_t': '发动机',
#      'qty1': '10',
#      'originCountry': 'CAN',
#      'codeTCompare': '发动机',
#      'qty1Compare': '10',
#      'originCountryCompare': 'BEN'},
#     {'code_t': '发动机',
#      'qty1': '10',
#      'originCountry': 'CAN',
#      'codeTCompare': '发动机',
#      'qty1Compare': '10',
#      'originCountryCompare': 'BEN'},
#     {'code_t': '发动机2',
#      'qty1': '10',
#      'originCountry': 'BOT',
#      'codeTCompare': '发动机2',
#      'qty1Compare': '10',
#      'originCountryCompare': 'ANG'},
#     {'code_t': '发动机3',
#      'qty1': '10',
#      'originCountry': 'KUW',
#      'codeTCompare': '发动机3',
#      'qty1Compare': '10',
#      'originCountryCompare': 'USA'},
#     {'code_t': '发动机3',
#      'qty1': '10',
#      'originCountry': 'KUW',
#      'codeTCompare': '发动机3',
#      'qty1Compare': '10',
#      'originCountryCompare': 'USA'},
#     {'code_t': '发动机3',
#      'qty1': '10',
#      'originCountry': 'KUW',
#      'codeTCompare': '发动机3',
#      'qty1Compare': '10',
#      'originCountryCompare': 'USA'},
#     {'code_t': '发动机',
#      'qty1': '10',
#      'originCountry': 'CAN',
#      'codeTCompare': '发动机',
#      'qty1Compare': '10',
#      'originCountryCompare': 'BEN'},
#     {'code_t': '发动机',
#      'qty1': '10',
#      'originCountry': 'CAN',
#      'codeTCompare': '发动机',
#      'qty1Compare': '10',
#      'originCountryCompare': 'BEN'},
#     {'code_t': '发动机',
#      'qty1': '10',
#      'originCountry': 'CAN',
#      'codeTCompare': '发动机',
#      'qty1Compare': '10',
#      'originCountryCompare': 'BEN'},
#     {'code_t': '发动机2',
#      'qty1': '10',
#      'originCountry': 'BOT',
#      'codeTCompare': '发动机2',
#      'qty1Compare': '10',
#      'originCountryCompare': 'ANG'}],
#    'ownerCode': '91310000785178414H',
#    'ownerName': '施洁医疗技术（上海）有限公司',
#    'ownerCodeCompare': '91310000785178414H',
#    'ownerNameCompare': '施洁医疗技术（上海）有限公司'}]}
